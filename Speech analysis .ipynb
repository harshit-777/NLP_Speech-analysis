# %%
from bs4 import BeautifulSoup
import nltk
from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from textblob import TextBlob
import string
from collections import  Counter
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud
import seaborn as sns
sns.set_context('notebook')
import warnings
warnings.filterwarnings("ignore")

# %%
htmlfile = open('Reserve Bank of India - Speeches.html',encoding="utf8").read()

# %%
soup = BeautifulSoup(htmlfile)

# %%
for speech_text_1 in soup.findAll(attrs={'class' : 'tablecontent2'}):
    speech_text_1 = speech_text_1.text.strip()
    
    # break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in speech_text_1.splitlines())
    # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    # drop blank lines
    speech_1 = '\n'.join(chunk for chunk in chunks if chunk)
    
print(speech_1)
# Out:
# At the outset, I wish to thank ASSOCHAM for inviting me to their 15th Annual Banking Summit. More so because this is ASSOCHAM’s centenary year. It is a remarkable accomplishment and I extend warm greetings to all those associated with ASSOCHAM. Over the years, ASSOCHAM has transformed itself into a forceful, proactive, forward-looking organisation to meet the aspirations of Indian business. I am certain that ASSOCHAM’s journey towards excellence will continue. 2. In a country like India with a population size of about 1.3 billion, the Micro, Small and Medium Enterprises (MSME) sector has a vital role in the economy. It fosters entrepreneurship and generates large employment opportunities. As MSMEs absorb the surplus agricultural labour, they help reduce the problem of disguised unemployment in rural areas. MSMEs are also complementary to large industries as ancillary units and also play an important role in the whole eco-system of the secondary and tertiary sector. 3. We all are awar
# ...

# %%
htmlfile = open('Reserve Bank of India - Speeches1.html',encoding="utf8").read()
soup = BeautifulSoup(htmlfile)
for speech_text_2 in soup.findAll(attrs={'class' : 'tablecontent2'}):
    speech_text_2 = speech_text_2.text.strip()
    
    # break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in speech_text_2.splitlines())
    # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    # drop blank lines
    speech_2 = '\n'.join(chunk for chunk in chunks if chunk)
    
print(speech_2)
# Out:
# It is indeed a matter of great pleasure for me to be here today in the Annual Banking Conclave of the Mint. I am told that this is the 13th edition of Conclave in what has become a prestigious annual event attracting the best and brightest minds of the finance and banking industry. This Conclave provides an important platform to all stakeholders in India’s financial and banking sector for assessing where we stand today and preparing ourselves for where we want to reach tomorrow.
# ...

# %%
htmlfile = open('Reserve Bank of India - Speeches2.html',encoding="utf8").read()
soup = BeautifulSoup(htmlfile)
for speech_text_3 in soup.findAll(attrs={'class' : 'tablecontent2'}):
    speech_text_3 = speech_text_3.text.strip()
    
    # break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in speech_text_3.splitlines())
    # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    # drop blank lines
    speech_3 = '\n'.join(chunk for chunk in chunks if chunk)
    
print(speech_3)
# Out:
# I am delighted to be back in my alma mater. Being here, brings back a surge of memories. Today, I wish to dwell upon a few aspects of central banking in the Indian context and RBI’s role in the current situation. I shall specifically focus on the evolution of monetary policy regimes in India and if I am to use the poetic license of Shakespeare, may I call it the seven ages of India’s monetary policy? 2. The history of central banking goes back to the seventeenth century when the first institution, ‘the Riksbank’, recognised as a central bank was set up in Sweden in 1668. Set up as a joint stock bank, it was chartered to lend funds to the government and to act as a clearing house for commerce. Later on, the Riksbank abandoned commercial lending and was granted a monopoly for issuing banknotes in 1897. Subsequently, several countries set up institutions that functioned as central banks. These early central banks like the Bank of England and Banque de France, though set up with private 
# ...

# %%
shrikanth_speeches = (speech_1 +"\n"+ speech_2 +"\n"+ speech_3)
print(shrikanth_speeches)
# Out:
# At the outset, I wish to thank ASSOCHAM for inviting me to their 15th Annual Banking Summit. More so because this is ASSOCHAM’s centenary year. It is a remarkable accomplishment and I extend warm greetings to all those associated with ASSOCHAM. Over the years, ASSOCHAM has transformed itself into a forceful, proactive, forward-looking organisation to meet the aspirations of Indian business. I am certain that ASSOCHAM’s journey towards excellence will continue. 2. In a country like India with a population size of about 1.3 billion, the Micro, Small and Medium Enterprises (MSME) sector has a vital role in the economy. It fosters entrepreneurship and generates large employment opportunities. As MSMEs absorb the surplus agricultural labour, they help reduce the problem of disguised unemployment in rural areas. MSMEs are also complementary to large industries as ancillary units and also play an important role in the whole eco-system of the secondary and tertiary sector. 3. We all are awar
# ...

# %%
tokenized_text=sent_tokenize(shrikanth_speeches)
print(tokenized_text)
# Out:
# ['At the outset, I wish to thank ASSOCHAM for inviting me to their 15th Annual Banking Summit.', 'More so because this is ASSOCHAM’s centenary year.', 'It is a remarkable accomplishment and I extend warm greetings to all those associated with ASSOCHAM.', 'Over the years, ASSOCHAM has transformed itself into a forceful, proactive, forward-looking organisation to meet the aspirations of Indian business.', 'I am certain that ASSOCHAM’s journey towards excellence will continue.', '2.', 'In a country like India with a population size of about 1.3 billion, the Micro, Small and Medium Enterprises (MSME) sector has a vital role in the economy.', 'It fosters entrepreneurship and generates large employment opportunities.', 'As MSMEs absorb the surplus agricultural labour, they help reduce the problem of disguised unemployment in rural areas.', 'MSMEs are also complementary to large industries as ancillary units and also play an important role in the whole eco-system of the secondary and tertia
# ...

# %%
tokenized_word=word_tokenize(shrikanth_speeches)
print(tokenized_word)
# Out:
# ['At', 'the', 'outset', ',', 'I', 'wish', 'to', 'thank', 'ASSOCHAM', 'for', 'inviting', 'me', 'to', 'their', '15th', 'Annual', 'Banking', 'Summit', '.', 'More', 'so', 'because', 'this', 'is', 'ASSOCHAM', '’', 's', 'centenary', 'year', '.', 'It', 'is', 'a', 'remarkable', 'accomplishment', 'and', 'I', 'extend', 'warm', 'greetings', 'to', 'all', 'those', 'associated', 'with', 'ASSOCHAM', '.', 'Over', 'the', 'years', ',', 'ASSOCHAM', 'has', 'transformed', 'itself', 'into', 'a', 'forceful', ',', 'proactive', ',', 'forward-looking', 'organisation', 'to', 'meet', 'the', 'aspirations', 'of', 'Indian', 'business', '.', 'I', 'am', 'certain', 'that', 'ASSOCHAM', '’', 's', 'journey', 'towards', 'excellence', 'will', 'continue', '.', '2', '.', 'In', 'a', 'country', 'like', 'India', 'with', 'a', 'population', 'size', 'of', 'about', '1.3', 'billion', ',', 'the', 'Micro', ',', 'Small', 'and', 'Medium', 'Enterprises', '(', 'MSME', ')', 'sector', 'has', 'a', 'vital', 'role', 'in', 'the', 'economy', '.
# ...

# %%
fdist = FreqDist(tokenized_word)
print(fdist)
# Out:
# <FreqDist with 2491 samples and 10931 outcomes>

# %%
fdist.most_common(10)
# Out:
# [('the', 571),
#  ('.', 493),
#  (',', 466),
#  ('of', 430),
#  ('and', 314),
#  ('to', 289),
#  ('in', 249),
#  ('a', 142),
#  ('for', 97),
#  ('on', 82)]

# %%
fdist.plot(30,cumulative=False)
plt.show()

# %%
stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# {'s', 'this', 'her', 'myself', 'these', "don't", 'theirs', "should've", 'most', 'doing', 'what', 'same', 'should', 'again', 'when', 'other', 'them', 'both', 'o', 'were', 'down', 'than', "weren't", 'on', 'own', 'under', 'is', 'some', 'if', 'ourselves', 'a', 'y', 'itself', "you'd", 'no', 'ours', 'where', 'aren', 'so', 'while', 'd', 'my', 'who', "isn't", 'why', 'below', 'how', "needn't", 'weren', "haven't", 'hasn', 'any', 'had', 'his', 'm', 'yours', "shouldn't", 'in', 'am', 'here', 'our', 'over', 'we', 'all', 'me', "hasn't", 'be', 'ain', 'do', 'yourself', 'and', 'himself', 'because', "you'll", 'shouldn', 'out', 'by', 'up', 'wasn', 'not', 'didn', "doesn't", 'there', 'until', 'mustn', 'whom', 'which', 'after', 'you', "she's", 'into', 'yourselves', 'each', 'was', "couldn't", 'only', "you're", 'then', 're', 'above', 'nor', 'they', 'to', 'i', 'haven', "shan't", 'between', 'at', "it's", 'from', 'will', 'shan', 'are', 've', 'has', 'through', 'wouldn', "mustn't", 'very', 'does', 'during', 'can'
# ...

# %%
filtered_word=[]
for w in tokenized_word:
    if w not in stop_words:
        filtered_word.append(w)
print("Tokenized Words:",tokenized_word[:500])
print("Filterd Words:",filtered_word[:500])
# Out:
# Tokenized Words: ['At', 'the', 'outset', ',', 'I', 'wish', 'to', 'thank', 'ASSOCHAM', 'for', 'inviting', 'me', 'to', 'their', '15th', 'Annual', 'Banking', 'Summit', '.', 'More', 'so', 'because', 'this', 'is', 'ASSOCHAM', '’', 's', 'centenary', 'year', '.', 'It', 'is', 'a', 'remarkable', 'accomplishment', 'and', 'I', 'extend', 'warm', 'greetings', 'to', 'all', 'those', 'associated', 'with', 'ASSOCHAM', '.', 'Over', 'the', 'years', ',', 'ASSOCHAM', 'has', 'transformed', 'itself', 'into', 'a', 'forceful', ',', 'proactive', ',', 'forward-looking', 'organisation', 'to', 'meet', 'the', 'aspirations', 'of', 'Indian', 'business', '.', 'I', 'am', 'certain', 'that', 'ASSOCHAM', '’', 's', 'journey', 'towards', 'excellence', 'will', 'continue', '.', '2', '.', 'In', 'a', 'country', 'like', 'India', 'with', 'a', 'population', 'size', 'of', 'about', '1.3', 'billion', ',', 'the', 'Micro', ',', 'Small', 'and', 'Medium', 'Enterprises', '(', 'MSME', ')', 'sector', 'has', 'a', 'vital', 'role', 'in', 'th
# ...

# %%
fdist.plot(30,cumulative=False)
plt.show()

# %%
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in filtered_word]
print(stripped[:400])
# Out:
# ['At', 'outset', '', 'I', 'wish', 'thank', 'ASSOCHAM', 'inviting', '15th', 'Annual', 'Banking', 'Summit', '', 'More', 'ASSOCHAM', '’', 'centenary', 'year', '', 'It', 'remarkable', 'accomplishment', 'I', 'extend', 'warm', 'greetings', 'associated', 'ASSOCHAM', '', 'Over', 'years', '', 'ASSOCHAM', 'transformed', 'forceful', '', 'proactive', '', 'forwardlooking', 'organisation', 'meet', 'aspirations', 'Indian', 'business', '', 'I', 'certain', 'ASSOCHAM', '’', 'journey', 'towards', 'excellence', 'continue', '', '2', '', 'In', 'country', 'like', 'India', 'population', 'size', '13', 'billion', '', 'Micro', '', 'Small', 'Medium', 'Enterprises', '', 'MSME', '', 'sector', 'vital', 'role', 'economy', '', 'It', 'fosters', 'entrepreneurship', 'generates', 'large', 'employment', 'opportunities', '', 'As', 'MSMEs', 'absorb', 'surplus', 'agricultural', 'labour', '', 'help', 'reduce', 'problem', 'disguised', 'unemployment', 'rural', 'areas', '', 'MSMEs', 'also', 'complementary', 'large', 'industries
# ...

# %%
filtered_words = [word for word in stripped if word.isalpha()]
print(filtered_words[:300])
# Out:
# ['At', 'outset', 'I', 'wish', 'thank', 'ASSOCHAM', 'inviting', 'Annual', 'Banking', 'Summit', 'More', 'ASSOCHAM', 'centenary', 'year', 'It', 'remarkable', 'accomplishment', 'I', 'extend', 'warm', 'greetings', 'associated', 'ASSOCHAM', 'Over', 'years', 'ASSOCHAM', 'transformed', 'forceful', 'proactive', 'forwardlooking', 'organisation', 'meet', 'aspirations', 'Indian', 'business', 'I', 'certain', 'ASSOCHAM', 'journey', 'towards', 'excellence', 'continue', 'In', 'country', 'like', 'India', 'population', 'size', 'billion', 'Micro', 'Small', 'Medium', 'Enterprises', 'MSME', 'sector', 'vital', 'role', 'economy', 'It', 'fosters', 'entrepreneurship', 'generates', 'large', 'employment', 'opportunities', 'As', 'MSMEs', 'absorb', 'surplus', 'agricultural', 'labour', 'help', 'reduce', 'problem', 'disguised', 'unemployment', 'rural', 'areas', 'MSMEs', 'also', 'complementary', 'large', 'industries', 'ancillary', 'units', 'also', 'play', 'important', 'role', 'whole', 'ecosystem', 'secondary', 'ter
# ...

# %%
ps = PorterStemmer()

stemmed_words=[]
for w in filtered_words:
    stemmed_words.append(ps.stem(w))
    
print("Filtered Words:",filtered_words[:100])
print("Stemmed Words:",stemmed_words[:100])
# Out:
# Filtered Words: ['At', 'outset', 'I', 'wish', 'thank', 'ASSOCHAM', 'inviting', 'Annual', 'Banking', 'Summit', 'More', 'ASSOCHAM', 'centenary', 'year', 'It', 'remarkable', 'accomplishment', 'I', 'extend', 'warm', 'greetings', 'associated', 'ASSOCHAM', 'Over', 'years', 'ASSOCHAM', 'transformed', 'forceful', 'proactive', 'forwardlooking', 'organisation', 'meet', 'aspirations', 'Indian', 'business', 'I', 'certain', 'ASSOCHAM', 'journey', 'towards', 'excellence', 'continue', 'In', 'country', 'like', 'India', 'population', 'size', 'billion', 'Micro', 'Small', 'Medium', 'Enterprises', 'MSME', 'sector', 'vital', 'role', 'economy', 'It', 'fosters', 'entrepreneurship', 'generates', 'large', 'employment', 'opportunities', 'As', 'MSMEs', 'absorb', 'surplus', 'agricultural', 'labour', 'help', 'reduce', 'problem', 'disguised', 'unemployment', 'rural', 'areas', 'MSMEs', 'also', 'complementary', 'large', 'industries', 'ancillary', 'units', 'also', 'play', 'important', 'role', 'whole', 'ecosystem', '
# ...

# %%
lem = WordNetLemmatizer()

lemma_words=[]
for w in filtered_words:
    lemma_words.append(lem.lemmatize(w))
    
print("Filtered Words:",filtered_words[:100])
print("Lemmatize Words:",lemma_words[:100])
# Out:
# Filtered Words: ['At', 'outset', 'I', 'wish', 'thank', 'ASSOCHAM', 'inviting', 'Annual', 'Banking', 'Summit', 'More', 'ASSOCHAM', 'centenary', 'year', 'It', 'remarkable', 'accomplishment', 'I', 'extend', 'warm', 'greetings', 'associated', 'ASSOCHAM', 'Over', 'years', 'ASSOCHAM', 'transformed', 'forceful', 'proactive', 'forwardlooking', 'organisation', 'meet', 'aspirations', 'Indian', 'business', 'I', 'certain', 'ASSOCHAM', 'journey', 'towards', 'excellence', 'continue', 'In', 'country', 'like', 'India', 'population', 'size', 'billion', 'Micro', 'Small', 'Medium', 'Enterprises', 'MSME', 'sector', 'vital', 'role', 'economy', 'It', 'fosters', 'entrepreneurship', 'generates', 'large', 'employment', 'opportunities', 'As', 'MSMEs', 'absorb', 'surplus', 'agricultural', 'labour', 'help', 'reduce', 'problem', 'disguised', 'unemployment', 'rural', 'areas', 'MSMEs', 'also', 'complementary', 'large', 'industries', 'ancillary', 'units', 'also', 'play', 'important', 'role', 'whole', 'ecosystem', '
# ...

# %%
print('Total number of words after text pre-processing :', len(lemma_words))
# Out:
# Total number of words after text pre-processing : 6008

# %%
filtered_speech_words = str(lemma_words)

wordcloud = WordCloud(width=1000, height=500,
                      random_state=30, max_font_size=110).generate(filtered_speech_words)
plt.figure(figsize=(18, 18))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
speech_word_counts = Counter(lemma_words)
common_words = [word[0] for word in speech_word_counts.most_common(25)]
common_counts = [word[1] for word in speech_word_counts.most_common(25)]

# Using background style
plt.style.use('dark_background')
plt.figure(figsize=(18, 15))

sns.barplot(x=common_words, y=common_counts)
plt.title('Most Common Words used by Shrikant')
plt.show()

# %%
for word, count in speech_word_counts.most_common(25):
    print("{}\t\t{}".format(word, count))
# Out:
# policy		76
# financial		71
# bank		69
# sector		66
# monetary		66
# The		64
# banking		48
# Bank		46
# market		46
# also		41
# India		38
# Reserve		38
# credit		38
# In		37
# growth		36
# system		34
# framework		32
# inflation		32
# MSME		31
# economy		30
# payment		29
# per		28
# rate		28
# MSMEs		25
# cent		25

# %%
speech_text_object = TextBlob(filtered_speech_words)

# textblob has a pre-trained sentiment analysis model that we can use
speech_text_object.sentiment
# Out:
# Sentiment(polarity=0.09255913630274243, subjectivity=0.3414782830128101)

# %%
plt.figure(figsize=(18,15))

# for each word draw the text on the char using the sentiment score as the x and y coordinates
for word in lemma_words:
    word_sentiment = TextBlob(word).sentiment
    plt.text(word_sentiment.polarity, # x coordinate
             word_sentiment.subjectivity, # y coordinate
             word) # the text to draw

# set axis ranges 
plt.xlim(-1, 1)
plt.ylim(0, 1)

# draw line in middle
plt.axvline(0, color='red', linestyle='dashed')

# label axis
plt.title('Sentiment analysis of words from shirkant speech\n')
plt.xlabel('Polarity (Negative or Positive)')
plt.ylabel('Subjectivity (0 - purly objective, 1 - purly subjective)')

# display
plt.show()
